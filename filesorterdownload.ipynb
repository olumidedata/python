# %%
import os, shutil

# %%
path =r"C:/Users/Olumide Kolawole/Downloads/"

# %%
os.listdir(path)
# Out:
# ['16-2021.zip',
#  '7z2301-x64.exe',
#  'Afif Moh Taj - Surah Al Baqarah Full سورة البقرة كاملة بدون اعلانات الشيخ عفيف محمد تاج.mp4',
#  'Anaconda3-2024.06-1-Windows-x86_64.exe',
#  'archive (1).zip',
#  'archive.zip',
#  'calendar.csv.gz',
#  'Data Cleaning Excel Tutorial.xlsx',
#  'desktop.ini',
#  'DOC-20240625-WA0044. (1).pdf',
#  'DOC-20240625-WA0044..pdf',
#  'DSC_0641.JPG',
#  'DSC_6876.JPG',
#  'DSC_6892.JPG',
#  'DSC_6895.JPG',
#  'DSC_6896.JPG',
#  'DSC_6900.JPG',
#  'DSC_6908.JPG',
#  'DSC_6909.JPG',
#  'DSC_6939.JPG',
#  'DSC_6942.JPG',
#  'DSC_6948.JPG',
#  'DSC_6951.JPG',
#  'DSC_6952.JPG',
#  'DSC_6953.JPG',
#  'DSC_6994.JPG',
#  'DSC_7001.JPG',
#  'DSC_7033.JPG',
#  'DSC_7179.JPG',
#  'DSC_7183.JPG',
#  'DSC_7204.JPG',
#  'DSC_7332.JPG',
#  'DSC_7339.JPG',
#  'DSC_8285.JPG',
#  'Dua Book Ramadan 2021 - QuranLyfe.pdf',
#  'easy-slider-revolution.1.1.0.zip',
#  'easy-slider-revolution.zip',
#  'FRONT VIEW.jpg',
#  'GatewayInstall.exe',
# ...

# %%
file_name = os.listdir(path)

# %%
os.listdir(path)
# Out:
# ['16-2021.zip',
#  '7z2301-x64.exe',
#  'Afif Moh Taj - Surah Al Baqarah Full سورة البقرة كاملة بدون اعلانات الشيخ عفيف محمد تاج.mp4',
#  'Anaconda3-2024.06-1-Windows-x86_64.exe',
#  'archive (1).zip',
#  'archive.zip',
#  'calendar.csv.gz',
#  'Data Cleaning Excel Tutorial.xlsx',
#  'desktop.ini',
#  'DOC-20240625-WA0044. (1).pdf',
#  'DOC-20240625-WA0044..pdf',
#  'DSC_0641.JPG',
#  'DSC_6876.JPG',
#  'DSC_6892.JPG',
#  'DSC_6895.JPG',
#  'DSC_6896.JPG',
#  'DSC_6900.JPG',
#  'DSC_6908.JPG',
#  'DSC_6909.JPG',
#  'DSC_6939.JPG',
#  'DSC_6942.JPG',
#  'DSC_6948.JPG',
#  'DSC_6951.JPG',
#  'DSC_6952.JPG',
#  'DSC_6953.JPG',
#  'DSC_6994.JPG',
#  'DSC_7001.JPG',
#  'DSC_7033.JPG',
#  'DSC_7179.JPG',
#  'DSC_7183.JPG',
#  'DSC_7204.JPG',
#  'DSC_7332.JPG',
#  'DSC_7339.JPG',
#  'DSC_8285.JPG',
#  'Dua Book Ramadan 2021 - QuranLyfe.pdf',
#  'easy-slider-revolution.1.1.0.zip',
#  'easy-slider-revolution.zip',
#  'FRONT VIEW.jpg',
#  'GatewayInstall.exe',
# ...

# %%
folder_names = ['Image files', 'Doc files', 'Excel Files', 'PDF', 'EXE', 'ZIP', 'MP4']
for loop in range(0,8):
        if not os.path.exists(path + folder_names[loop]):
            print(path + folder_names[loop])
            os.makedirs(path + folder_names[loop])
# Out:
# C:/Users/Olumide Kolawole/Downloads/MP4
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 3
#       1 folder_names = ['Image files', 'Doc files', 'Excel Files', 'PDF', 'EXE', 'ZIP', 'MP4']
#       2 for loop in range(0,8):
# ----> 3         if not os.path.exists(path + folder_names[loop]):
#       4             print(path + folder_names[loop])
#       5             os.makedirs(path + folder_names[loop])
#
# IndexError: list index out of range

# %%
for file in file_name:
    if ".jpg" in file and not os.path.exists(path + "Image files/" + file):
        shutil.move(path + file, path + "Image files/" + file)
    if ".jpeg" in file and not os.path.exists(path + "Image files/" + file):
        shutil.move(path + file, path + "Image files/" + file)
    elif ".xlsx" in file and not os.path.exists(path + "Excel files/" + file):
        shutil.move(path + file, path + "Excel files/" + file)
    elif ".doc" in file and not os.path.exists(path + "Doc files/" + file):
        shutil.move(path + file, path + "Doc files/" + file)
    elif ".docx" in file and not os.path.exists(path + "Doc files/" + file):
        shutil.move(path + file, path + "Doc files/" + file)
    elif ".pdf" in file and not os.path.exists(path + "PDF/" + file):
        shutil.move(path + file, path + "PDF/" + file)
    elif ".exe" in file and not os.path.exists(path + "EXE/" + file):
        shutil.move(path + file, path + "EXE/" + file)
    elif ".zip" in file and not os.path.exists(path + "ZIP/" + file):
        shutil.move(path + file, path + "ZIP/" + file)

# %%
for file in file_name:
    if ".JPG" in file and not os.path.exists(path + "Image files/" + file):
        shutil.move(path + file, path + "Image files/" + file)

# %%
for file in file_name:
    if ".mp4" in file and not os.path.exists(path + "MP4/" + file):
        shutil.move(path + file, path + "MP4/" + file)
